# %%
import pandas as pd

# %%
Vendettanames = {'name': ['Nic', 'Luca', 'Nic', 'Luca', 'Nic', 'Luca'], 'Namecount':[425,282,302,366,299,508]}
Titles = ['Vendetta', 'Vendetta', 'Inferno', 'Inferno', 'Mafiosa', 'Mafiosa']
Vendetta = pd.DataFrame(Vendettanames, index=Titles)
Vendetta
# Out:
#           name  Namecount
# Vendetta   Nic        425
# Vendetta  Luca        282
# Inferno    Nic        302
# Inferno   Luca        366
# Mafiosa    Nic        299
# Mafiosa   Luca        508

# %%
Nic = [425, 302,299]
Luca = [282,366,508]
index = ['Vendetta', 'Inferno', 'Mafiosa']
df = pd.DataFrame({'Nic': Nic,'Luca': Luca}, index=index)
ax = df.plot.bar(rot=0)
ax

# %%
df = pd.DataFrame({'Nic':[425,302,299] ,'Luca': [282,366,508]}, index=index)
lines = df.plot.line()
lines
axes = df.plot.line(subplots=True)
type(axes)
# Out:
# numpy.ndarray
