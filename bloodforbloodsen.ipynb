# %%
import pandas as pd

# %%
bloodforbloodsen = {'name': ['Nic', 'Luca', 'Nic', 'Luca', 'Nic', 'Luca'], 'Positive':[139,51,68,76,69,128], 'Negative':[105, 71, 69, 90, 58, 130], 'Neutral':[66, 35, 29, 26, 20, 46]}
Titles = ['Vendetta', 'Vendetta', 'Inferno', 'Inferno', 'Mafiosa', 'Mafiosa']
books = pd.DataFrame(bloodforbloodsen, index=Titles)
books
# Out:
#           name  Positive  Negative  Neutral
# Vendetta   Nic       139       105       66
# Vendetta  Luca        51        71       35
# Inferno    Nic        68        69       29
# Inferno   Luca        76        90       26
# Mafiosa    Nic        69        58       20
# Mafiosa   Luca       128       130       46

# %%
Nic = [139, 105, 66]
Luca = [51,71, 35]
index = ['Positive', 'Negative', 'Neutral']
df = pd.DataFrame({'Nic': Nic,'Luca': Luca}, index=index)
ax = df.plot.bar(rot=0)
ax

# %%
Nic = [68, 69, 29]
Luca = [76,90, 26]
index = ['Positive', 'Negative', 'Neutral']
df = pd.DataFrame({'Nic': Nic,'Luca': Luca}, index=index)
ax = df.plot.bar(rot=0)
ax

# %%
Nic = [69, 58, 20]
Luca = [128, 130, 46]
index = ['Positive', 'Negative', 'Neutral']
df = pd.DataFrame({'Nic': Nic,'Luca': Luca}, index=index)
ax = df.plot.bar(rot=0)
ax

# %%
df = pd.DataFrame({'Nic':[139, 105, 66] ,'Luca':[51,71, 35]}, index=index)
lines = df.plot.line()
lines
axes = df.plot.line(subplots=True)
type(axes)
# Out:
# numpy.ndarray

# %%
df = pd.DataFrame({'Nic':[68, 69, 29] ,'Luca':[76,90, 26]}, index=index)
lines = df.plot.line()
lines
axes = df.plot.line(subplots=True)
type(axes)
# Out:
# numpy.ndarray

# %%
df = pd.DataFrame({'Nic':[69, 58, 20] ,'Luca':[128, 130, 46]}, index=index)
lines = df.plot.line()
lines
axes = df.plot.line(subplots=True)
type(axes)
# Out:
# numpy.ndarray
